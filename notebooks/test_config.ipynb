# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import config

print(config.RANDOM_SEED)
print(config.DEVICE)
print(config.BATCH_SIZE)
print(config.DATASET_DIR)
# Out:
# 42
# cpu
# 16
# C:\Users\bevan\Desktop\Paraphrase_Detection_Generation\datasets
